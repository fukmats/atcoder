# %%
N = 7
h = [2,9,4,5,1,6,10]
dp = []

# %%
n=1
dp[n-1] = 0
n=2
dp[n-1] = h[n-1]-
#3
dp[n-1] = dp[n-2]+h[n-1]
dp[n-1] = dp[n-3]+h[]
# Out:
# 2

# %%
min_cost = []
def ch_min(a,b):
    if a > b:
        a = b
        return True
    else:
        return False

N = int(input())
h = list(map(lambda h: int(h), input().split()))

min_cost = [99999 for _ in range(N)]
for i in range(N):
    if i == 0:
        min_cost[i] = 0
        continue
    if i == 1:
        min_cost[i] = h[i]-h[i-1]
        continue
    ch_min(min_cost[i], h[i]-h[i-1]+min_cost[i-1])
    ch_min(min_cost[i], h[i]-h[i-2]+min_cost[i-2])

print(min_cost[N-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/yy/5vn5bk_d7kq_wrl03_9g4rl00000gn/T/ipykernel_91556/4093222871.py in <module>
#      21     ch_min(min_cost[i], h[i]-h[i-2]+min_cost[i-2])
#      22
# ---> 23 print(min_cost[N])
#      24
#      25
#
# IndexError: list index out of range

# %%
import time
import bisect
import numpy as np
n=10**6
a=list(range(n))
b=list(range(n))
c=np.array(range(n),dtype="int64")
d=np.array(range(n),dtype="int64")

#numpyなし
t1=time.time()
for i in range(n):
    j=bisect.bisect_left(a,b[i])
t2=time.time()
print(t2-t1)

#numpyあり
t3=time.time()
js=np.searchsorted(c,d)
t4=time.time()
print(t4-t3)
# Out:
# 0.3430027961730957
# 0.09231901168823242
